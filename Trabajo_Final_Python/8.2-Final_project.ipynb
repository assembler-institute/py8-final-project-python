# %% [markdown]
# # Initial analysis of the text document
#
#
# After visual inspection of the text document, **a short script was created to understand the basic structure of the .txt file** that is going to be the core of this project.
#
# Very briefly, the data sctructure is as follows: every entry on the document has a maximum of 3 fields (name, URL and description). Some of the entries are missing a field.
#
# The information that was extracted in this initial analysis is:
#
# - Total number of lines: 1975
# - Total number of blank spaces: 128
# - Total number of comments: 57
#
# After cleaning it is expected that the document will have **1790 valid entries**.

# %%
with open("Files/data.txt", "r") as f:
    
    # A list of all the entries is stored in lst variable
    lst = f.readlines()
    
    # Several counters are initialize
    blank_counter = 0
    comment_counter = 0
    line_counter = 0
    
    for item in lst:
        
        line_counter += 1
        
        #Blank lines always have a new line character (/n)
        if item == "\n":
            blank_counter += 1
        
        # Comments always start with %, # or * characters
        elif item[0] in "%#*":
            comment_counter += 1

# General information is printed on screen
print(f'Lines: {line_counter}\nBlank spaces: {blank_counter}\nComments: {comment_counter}\n\nLines after cleaning: {line_counter-blank_counter-comment_counter}')
# Out:
# Lines: 1790
# Blank spaces: 0
# Comments: 0
#
# Lines after cleaning: 1790

# %% [markdown]
# # Data cleaning and transforming
#
# To ensure a correct data processing later on, **document must first be cleaned and transformed** into a manageable object type.
#
# After visual inspection of the text document, it is decided to remove the following elements:
#
# - <u>Comments</u>. All comments start with one of this characters: '%', '#' or '*'
# - <u>Blank lines</u>. All blank lines have only a new line character in them: '/n'
#
# After cleaning the data, **it is decided to transfer the document information into a list of sublist**, were each sublist matches an entry of the original document and each item on that sublist matches a field (Name, URL and Description).

# %%
from string import punctuation, whitespace

def read_and_clean(file, *args):
    
    '''
    Takes a file path and a variable number of characters (*args). When executed, it removes any invalid entry (blank 
    lines and lines starting with any of the characters introduced as *args) from the original file. It returns all 
    valid entries of the database grouped all together in a list of lists.
    '''
    
    # File is opened in reading mode
    with open(file, "r", encoding="utf-8") as f:
        
        # readlines() converts all lines on a file in a list where each line is an item. This list is stored in the 
        # variable lines.
        lines = f.readlines()

    lst = []
        # Every valid entry is appended into a new list
    for line in lines:
        if not line[0] in args and not line == "\n":
            lst.append(line)
            
    # The list of strings is converted into a list of lists for later use in other functions
    lst = list(map(lambda item: item.split(','), lst))

    # Unnecessary characters are removed from each item of the list
    lst_cleaned = []
    strip_chars = punctuation + whitespace
  
    for index, item in enumerate(lst):
        lst[index] =  list(map(lambda s: s.strip(strip_chars) , item))
    
    # The list with the valid entries is written into the file, eliminating the previous content
    with open('Files/data.txt', "w", encoding="utf-8") as f:
        for item in lst:
            f.writelines(f'{item[0]}, {item[1]}, {item[2]}\n')
    
    return lst

cleaned_data = read_and_clean("Files/data.txt", '#', '*', '%')

print(cleaned_data)
# Out:
# [['Advangle', 'http://advangle.com', 'Buscador genérico'], ['Aol', 'http://search.aol.com', 'Buscador genérico'], ['Ask', 'http://www.ask.com', 'Buscador genérico'], ['Bing', 'http://www.bing.com', 'Buscador genérico'], ['DuckDuckGo', 'https://duckduckgo.com', 'Buscador genérico'], ['Gigablast', 'http://gigablast.com', 'Buscador genérico'], ['Goodsearch', 'http://www.goodsearch.com', 'Buscador genérico'], ['Google Search', 'http://www.google.com', 'Buscador genérico'], ['Instya', 'http://www.instya.com', 'Buscador genérico'], ['Impersonal.me', 'http://www.impersonal.me', 'Buscador genérico'], ['iSEEK Education', 'http://education.iseek.com/iseek/home.page', 'Buscador genérico'], ['ixquick', 'https://www.ixquick.com', 'Buscador genérico'], ['Lycos', 'http://www.lycos.com', 'Buscador genérico'], ['Search.com', 'http://www.search.com', 'Buscador genérico'], ['SurfCanyon', 'http://www.surfcanyon.com', 'Buscador genérico'], ['Teoma', 'http://www.teoma.com', 'Buscador genérico'], ['Wolfram Alpha', 'http://www.wolframalpha.com', 'Buscador genérico'], ['Yahoo! Search', 'http://www.yahoo.com', 'Buscador genérico'], ['Alleba (Filipinas', 'http://www.alleba.com', 'Buscador local'], ['Baidu (China', 'http://www.baidu.com', 'Buscador local'], ['Eniro (Suecia', 'http://www.eniro.se', 'Buscador local'], ['Goo (Japan', 'http://www.goo.ne.jp', 'Buscador local'], ['Najdsi (Eslovenia', 'http://www.najdi.si', 'Buscador local'], ['Naver (Corea del Sur', 'http://www.naver.com', 'Buscador local'], ['Onet.pl (Polonia', 'http://www.onet.pl', 'Buscador local'], ['Orange (Francia', 'http://www.orange.fr', 'Buscador local'], ['Parseek (Iran', 'http://www.parseek.com', 'Buscador local'], ['SAPO (Portugal', 'http://www.sapo.pt', 'Buscador local'], ['Search.ch (Suiza', 'http://www.search.ch', 'Buscador local'], ['Walla (Israel', 'http://www.walla.co.il', 'Buscador local'], ['Yandex (Rusia', 'http://www.yandex.com', 'Buscador local'], ['All-in-One', 'http://all-io.net', 'Meta buscador'], ['AllTheInternet', 'http://www.alltheinternet.com', 'Meta buscador'], ['Etools', 'http://www.etools.ch', 'Meta buscador'], ['FaganFinder', 'http://www.faganfinder.com/engines', 'Meta buscador'], ['Goofram', 'http://www.goofram.com', 'Meta buscador'], ['iZito', 'http://www.izito.com', 'Meta buscador'], ['Nextaris', 'http://www.nextaris.com', 'Meta buscador'], ['Metabear', 'http://www.metabear.com', 'Meta buscador'], ['Myallsearch', 'http://www.myallsearch.com', 'Meta buscador'], ['Qwant', 'http://www.qwant.com', 'Meta buscador'], ['Sputtr', 'http://www.sputtr.com', 'Meta buscador'], ['Trovando', 'http://www.trovando.it', 'Meta buscador'], ['WebOasis', 'https://weboas.is', 'Meta buscador'], ['Zapmeta', 'http://www.zapmeta.com', 'Meta buscador'], ['2lingual Search', 'http://www.2lingual.com', 'Buscador especializado'], ['Biznar', 'http://biznar.com', 'Buscador especializado'], ['CiteSeerX', 'http://citeseer.ist.psu.edu', 'Buscador especializado'], ['Digle', 'https://www.digle.com', 'Buscador especializado'], ['Google Custom Search', 'http://www.google.com/cse', 'Buscador especializado'], ['Harmari (Unified Listings Search', 'https://www.harmari.com/search/unified', 'Buscador especializado'], ['Internet Archive', 'https://archive.org', 'Buscador especializado'], ['Million Short', 'https://millionshort.com', 'Buscador especializado'], ['WorldWideScience.org', 'http://worldwidescience.org', 'Buscador especializado'], ['Zanran', 'http://zanran.com', 'Buscador especializado'], ['Carrot2', 'http://search.carrot2.org', 'Buscador visual'], ['Yippy', 'http://yippy.com', 'Buscador visual'], ['Google Similar Pages', 'https://chrome.google.com/webstore/detail/google-similar-pages/pjnfggphgdjblhfjaphkjhfpiiekbbej', 'Buscadores por similitud'], ['SimilarSites', 'http://www.similarsites.com', 'Buscadores por similitud'], ['SitesLike', 'http://www.siteslike.com', 'Buscadores por similitud'], ['Authorstream', 'http://www.authorstream.com', 'Buscador de contenidos'], ['Find-pdf-doc', 'http://www ...

# %% [markdown]
# # Auxiliary functions
#
# To help debbuging and simplifying code in more advanced functions, some auxiliary functions are firstly defined.

# %% [markdown]
# ## features_picker_cleaner function
#
# This function takes the list of lists that was generated and cleaned in the previous function and returns a list of strings containing only one particular feature of the original document. Each feature is given an identifier number as follows:
#
# - 1 for the Name field
# - 2 for the URL field
# - 3 for the Description field
#
# Also, this function allows to introduce, some optional characters to be removed from each particular feature. For example the name “burrrd.”, which corresponds to one of the entries is replaced by “burrrd” if "." is introduced as an optional argument.
#
# All empty values are stored as 'n/a'.

# %%
def features_picker_cleaner(entries, feature, *args):
    
    '''
    Takes a list of sublists (every sublist represents a field in a database), an integer representing a feature 
    (Name, URL or Description) to be filtered of the sublist and a variable number of leftover characters to be 
    cleaned from every individual field. Returns only the filtered field in the form of a list of strings.
    '''
    
    lst = []
    
    # Every item on the list is iterated
    for line in entries:
        # The field of interest is accessed and stored in a variable
        field = line[feature-1]
        #print(field)
        #We add the fields that aren't empty to a new list that will only contain the selected feature
        if field:
            lst.append(field)
        else:
            # Empty fields are appended as n/a
            lst.append('n/a')
    
    # Leftover characters are removed from the items on the feature list
    for arg in args:
        lst = list(map(lambda s: s.replace(arg, ""), lst))

    return lst

filtered_field = features_picker_cleaner(cleaned_data, 3)
print(filtered_field)
# Out:
# ['Buscador genérico', 'Buscador genérico', 'Buscador genérico', 'Buscador genérico', 'Buscador genérico', 'Buscador genérico', 'Buscador genérico', 'Buscador genérico', 'Buscador genérico', 'Buscador genérico', 'Buscador genérico', 'Buscador genérico', 'Buscador genérico', 'Buscador genérico', 'Buscador genérico', 'Buscador genérico', 'Buscador genérico', 'Buscador genérico', 'Buscador local', 'Buscador local', 'Buscador local', 'Buscador local', 'Buscador local', 'Buscador local', 'Buscador local', 'Buscador local', 'Buscador local', 'Buscador local', 'Buscador local', 'Buscador local', 'Buscador local', 'Meta buscador', 'Meta buscador', 'Meta buscador', 'Meta buscador', 'Meta buscador', 'Meta buscador', 'Meta buscador', 'Meta buscador', 'Meta buscador', 'Meta buscador', 'Meta buscador', 'Meta buscador', 'Meta buscador', 'Meta buscador', 'Buscador especializado', 'Buscador especializado', 'Buscador especializado', 'Buscador especializado', 'Buscador especializado', 'Buscador especializado', 'Buscador especializado', 'Buscador especializado', 'Buscador especializado', 'Buscador especializado', 'Buscador visual', 'Buscador visual', 'Buscadores por similitud', 'Buscadores por similitud', 'Buscadores por similitud', 'Buscador de contenidos', 'Buscador de contenidos', 'Buscador de contenidos', 'Buscador de contenidos', 'Buscador de contenidos', 'Buscador de contenidos', 'Buscador de contenidos', 'Buscador de contenidos', 'Buscador de contenidos', 'Buscador de contenidos', 'Buscador de contenidos', 'Buscador código', 'Buscador código', 'Buscador código', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Redes Sociales', 'Buscador blogs', 'Buscador blogs', 'Buscador blogs', 'Buscador blogs', 'Buscador blogs', 'Buscador foros', 'Buscador foros', 'Buscador foros', 'Buscador foros', 'Buscador foros', 'Buscador foros', 'Buscador foros', 'Buscador foros', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twitter', 'Herramientas Twit ...

# %% [markdown]
# ## counter function
#
# To count the occurrences of a value inside a particular feature, a custom function is created. This function takes the list of strings created in the previous function and returns the number of occurrences of a particular value inside that list of strings.

# %%
from functools import reduce

def counter(value, where_to_look_for):
    
    '''
    Takes a list of strings and a value. Returns the number of occurrences of that value inside the list.
    '''
    
    # A boolean list is generated, where values that match the searched value return a 1 and the rest return 0. This boolean 
    # list is then summed to obtain the total of occurrences of that value.
    return sum(list(map(lambda field: 1 if field == value else 0, where_to_look_for)))


print(counter('Herramientas Instagram', filtered_field))
# Out:
# 7

# %% [markdown]
# ## values_and_frequencies function
#
# This function uses the previous function (occurrences counter function) to create a dictionary that maps each unique value of a feature with its number of occurrences.

# %%
def values_and_frequencies(where_to_look_for, min_num_repetitions=0):
    '''
    Takes a list of strings and a minimum number of repetitions. Returns a dictionary that maps each item of the list of strings
    with its frequence of occurrence.
    
    '''
    dict_freq = dict()
    
    # A unique values list can also be obtained by using high order functions as follows:
    # once_list = reduce(lambda x,y: [*x,y] if not y in x else x, where_to_look_for, [])
    
    once_list = set(where_to_look_for)
    
    # The list of unique values is iterated and the fields are passed to the counter function
    for field in once_list:
        
        # The number of occurrences of a particular field are calculated with counter function and stored in a variable
        n_rep = counter(field, where_to_look_for)
        
        # If the number of occurrences of a particular field surpasses the defined threshold, then it is stored inside 
        # a diccionary
        if(n_rep >= min_num_repetitions):
            dict_freq[field] = n_rep
            
    return dict_freq

print(values_and_frequencies(filtered_field))
# Out:
# {'Buscador foros': 8, 'Browsers': 17, 'Buscador genérico': 18, 'Dashboard Tools': 11, 'Meta buscador': 14, 'Buscador especializado': 10, 'Herramientas Instagram': 7, 'Buscador código': 3, 'Redes Sociales': 42, 'n/a': 1432, 'Q&A Sites': 6, 'Buscador visual': 2, 'Herramientas Twitter': 82, 'Wikis': 14, 'Buscador local': 13, 'Data and Statistics': 80, 'Herramientas Pinterest': 1, 'Buscadores por similitud': 3, 'Herramientas Reddit': 10, 'Buscador de contenidos': 11, 'Buscador blogs': 5, 'Herramientas Facebook': 1}

# %% [markdown]
# # filter_names function
#
# This function returns only the second half of a list of strings (filtered feature) after ordering it alphabetically.

# %%
def filter_names(num, where_to_look_for):
    
    '''
    Takes a number (that represents the field to be filtered) and a list of lists. Returns the second half of the 
    filtered field, after ordering it alphabetically.
    
    '''
      
    # The filtered field is obtained with the features_picker_cleaner
    lst = features_picker_cleaner(where_to_look_for, num)
    len_lst = len(lst)
  
    # If the length of the list is odd, the floor division by 2 is used to obtain the starting index of the returned list. 
    # Otherwise, if legth is even, normal division is used.
    if len_lst % 2 == 0:
        index = len_lst / 2
    else:
        index = len_lst // 2
    
    index = int(index)
    
    # To ensure a correct sorting, lower method is passed as key in sorted function to ensure that lower and upper cases are
    # sorted simultaneously.
    return sorted(lst[index:], key=lambda word: word.lower())

print(filter_names(2, cleaned_data))
# Out:
# ['http://92fiveapp.com', 'http://a.nnotate.com', 'http://alltop.com', 'http://annotatorjs.org', 'http://anydesk.com/remote-desktop', 'http://arborjs.org', 'http://atlas.cid.harvard.edu', 'http://auralink.com', 'http://beakernotebook.com', 'http://bitreading.com/deltafeed', 'http://bombbomb.com', 'http://bonzobox.com', 'http://booky.io', 'http://bunchapp.io', 'http://campayn.com', 'http://channelkit.com', 'http://chartico.com', 'http://charts.hohli.com', 'http://circos.ca', 'http://classeur.io', 'http://collabtive.o-dyn.de', 'http://comtrade.un.org', 'http://coowon.com', 'http://cosketch.com', 'http://create.visual.ly', 'http://creately.com', 'http://creately.com', 'http://croppola.com', 'http://crowdbase.com', 'http://ctrlq.org/rss', 'http://data.un.org', 'http://data.worldbank.org', 'http://datatopics.worldbank.org/consumption/home', 'http://datavizcatalogue.com', 'http://digg.com/login?next=%2Freader', 'http://diytoolkit.org/tools/fast-idea-generator-2', 'http://dmitrybaranovskiy.github.io/raphael', 'http://donottrack.us', 'http://doodle.com', 'http://draw.to', 'http://dropcanvas.com', 'http://dygraphs.com', 'http://ekiga.org', 'http://en.arguman.org', 'http://encfsmp.sourceforge.net', 'http://endnote.com', 'http://eraser.heidi.ie', 'http://evernote.com', 'http://f1000.com', 'http://feed.exileed.com', 'http://feed.janicek.co', 'http://feed43.com', 'http://fetchrss.com', 'http://flask.io', 'http://flask.io', 'http://flipboard.com', 'http://flockdraw.com', 'http://forums.peerblock.com', 'http://foswiki.org', 'http://fotoflexer.com', 'http://freemind.sourceforge.net/wiki/index.php/Main_Page', 'http://freeplane.sourceforge.net/wiki/index.php/Main_Page', 'http://freshmail.com', 'http://ge.tt', 'http://generator.acmi.net.au/storyboard', 'http://getpocket.com', 'http://getstache.com', 'http://groupzap.com', 'http://hdlab.stanford.edu/palladio', 'http://hdr.undp.org/en/data', 'http://helpmeviz.com', 'http://hiverhq.com', 'http://hugin.sourceforge.net', 'http://iab.worldbank.org', 'http://iloggo.com', 'http://imindmap.com/products/imindmap', 'http://infinitekind.com/syncspace', 'http://iqalerts.com', 'http://jpgraph.net', 'http://justdelete.me', 'http://kanbantool.com', 'http://kartograph.org', 'http://keeeb.com', 'http://keepass.info', 'http://kerika.com', 'http://kl1p.com', 'http://ksosoft.com/product/presentation-free.html', 'http://leafletjs.com', 'http://lib.stat.cmu.edu/DASL', 'http://lightzoneproject.org', 'http://linkurio.us', 'http://linkydink.io', 'http://listify.okfnlabs.org', 'http://literatureandlatte.com/scapple.php', 'http://literatureandlatte.com/scrivener.php', 'http://mag.io', 'http://mailchimp.com', 'http://masterpasswordapp.com', 'http://mind42.com', 'http://mobilimeet.com', 'http://moose-team.github.io/friends', 'http://mozy.com', 'http://myfav.es', 'http://neatline.org', 'http://newsblur.com', 'http://nixory.sourceforge.net', 'http://nodexl.codeplex.com', 'http://office.microsoft.com/en-us/onenote', 'http://offliberty.com', 'http://oicweave.org', 'http://omeka.org', 'http://onwebchange.com', 'http://openlayers.org', 'http://otranscribe.com', 'http://pageflow.io', 'http://papersapp.com', 'http://philogb.github.io/jit', 'http://pinstriped.com', 'http://pith.li', 'http://pomodorotechnique.com', 'http://popplet.com', 'http://primarypad.com', 'http://privazer.com', 'http://raw.densitydesign.org', 'http://reederapp.com', 'http://restya.com', 'http://restya.com', 'http://reverbapp.com', 'http://ricks-apps.com/osx/sitesucker/index.html', 'http://scadaplan.com', 'http://scribble.wreally.com', 'http://scribbleton.com', 'http://scylla.sh', 'http://sdelements.github.io/lets-chat', 'http://seashore.sourceforge.net', 'http://selfoss.aditu.de', 'http://sharetronix.com', 'http://simplenote.com', 'http://sketchboard.io', 'http://slidedog.com', 'http://slideidea.com', 'http://smallpdf.com', 'http://somcloud.com/about/somnote', 'http://spark.apache.org/graphx', 'http://square.github.io/crossfilter', 'http://squidnotes.com', 'http: ...

# %% [markdown]
# # domain_extraction function
#
# Used to obtain the unique values for the website domains on the URL feature. Uses the features_picker_cleaner function to obtain a list of strings for a particular feature and to eliminate some leftover characters, such as the Hypertext Transfer Protocol (HTTP). Web paths are also eliminated. Finally, some general information about the number of repeated domains is printed.

# %%
def domain_extraction(where_to_look_for):
    '''
    Takes a list of lists and extracts all the non-repeating webpage domains from the second field. Non-repeating 
    Webpage domains are finally returned in a list of strings.
    '''
    
    # Webpage domain field is first filtered from the original list of lists. Leftover characters to be cleaned are also
    # passed into the function.
    lst = features_picker_cleaner(where_to_look_for, 2, 'http://', 'https://', 'www.')
    
    #Path is removed to obtain the domain only
    for i in range(len(lst)):
        lst[i] = lst[i].split('/')[0]
    
    #Information on repeted domains is calculated with the values_and_frequencies function and is then displayed on screen.
    dic = values_and_frequencies(lst, 2)
    print(f'Number of repeated domains: {sum(dic.values())}')
    
    return set(lst)

domain_extraction(cleaned_data)
# Out:
# Number of repeated domains: 280
# {'videoscribe.co',
#  'tableausoftware.com',
#  'tinfoleak.com',
#  'icq.com',
#  'writeapp.me',
#  'videolink2.me',
#  'bookish.com',
#  'slangit.com',
#  'maven.co',
#  'diytoolkit.org',
#  'world-newspapers.com',
#  'sendinblue.com',
#  'haikudeck.com',
#  'facesaerch.com',
#  'create.visual.ly',
#  'rssowl.org',
#  'projectplace.com',
#  'goo.ne.jp',
#  'icloud.com',
#  'ceebd.co.uk',
#  'xmarks.com',
#  'tabula.technology',
#  'meetingone.com',
#  'vizala.com',
#  'silk.co',
#  'photobucket.com',
#  'captainfact.io',
#  'expertpages.com',
#  'zoho.com',
#  'chartjs.org',
#  'pomodorotechnique.com',
#  'archive.org',
#  'indiatyping.com',
#  'reederapp.com',
#  'worklife.com',
#  'ustart.org',
#  'fusioncharts.com',
#  'onehub.com',
#  'lockbin.com',
#  '2doapp.com',
#  'rememberthemilk.com',
#  'mediawiki.org',
#  'realtimeboard.com',
#  'slidedog.com',
#  'mattermap.nl',
#  'gigablast.com',
#  'instapaper.com',
#  'signupto.com',
#  'silentcircle.com',
#  'teoma.com',
#  'croppola.com',
#  'centbrowser.com',
#  'coowon.com',
#  'easy-annotate.com',
#  'piematrix.com',
#  'canlaw.com',
#  'start.io',
#  'ahrefs.com',
#  'experts.com',
#  'inspire-geoportal.ec.europa.eu',
#  'brave.com',
#  'linguee.com',
#  'freebooksearch.net',
#  'afp.com',
#  'booky.io',
#  'earthcam.com',
#  'worldlingo.com',
#  '5pmweb.com',
#  'onwebchange.com',
#  'assistant.to',
#  'wisemapping.com',
#  'adium.im',
#  'wickr.com',
#  'discover.twitter.com',
#  'prezi.com',
#  'remote.12dt.com',
#  'howlongtoreadthis.com',
#  'localfocus.nl',
#  'analyticsportfolio.com',
#  'crunchbase.com',
#  'blog.booksontheknob.org',
#  'unctad.org',
#  'prb.org',
#  'emergent.info',
#  'atlasify.com',
#  'flashearth.com',
#  'batchedinbox.com',
#  'reuters.com',
#  'icaew.com',
#  'translate.com',
#  'mind42.com',
#  'tineye.com',
#  'zim-wiki.org',
#  'pentest-tools.com',
#  'collaboratecloud.com',
#  'spoonbill.io',
#  'scadaplan.com',
#  '10000ft.com',
#  'vis.occrp.org',
#  '92fiveapp.com',
#  'scrible.com',
#  'youtube.com',
#  'ilovepdf.com',
#  'blinkist.com',
#  'medium.com',
#  'leatherbound.me',
#  'veeting.com',
#  'monster.com',
#  'ebscohost.com',
#  'search.aol.com',
#  'freedcamp.com',
#  'energyatlas.iea.org',
#  'weekdone.com',
#  'zeemaps.com',
#  'getstache.com',
#  'taskboard.matthewross.me',
#  'openingthebook.com',
#  'sputtr.com',
#  'inshorts.com',
#  'apple.com',
#  'scoop.it',
#  'netbootcamp.org',
#  'ciesin.org',
#  'hiverhq.com',
#  'ccsubs.com',
#  'mendeley.com',
#  'animatron.com',
#  'bitreading.com',
#  'voilanorbert.com',
#  'spydialer.com',
#  'journalseek.net',
#  'pinstriped.com',
#  'groupzap.com',
#  'sikuli.org',
#  'advangle.com',
#  'pgi.com',
#  'social-searcher.com',
#  'favable.com',
#  'symbaloo.com',
#  'adb.org',
#  'sendthisfile.com',
#  'skipease.com',
#  'xodo.com',
#  'sleepingtime.org',
#  'trovando.it',
#  'yugma.com',
#  'twoodo.com',
#  'constantcontact.com',
#  'manualslib.com',
#  'targetolog.com',
#  'jstor.org',
#  'greylit.org',
#  'familysearch.org',
#  'twitonomy.com',
#  'unctadstat.unctad.org',
#  'goodsearch.com',
#  'mapline.com',
#  'twazzup.com',
#  'geocreepy.com',
#  'aviary.com',
#  'iqalerts.com',
#  'sapo.pt',
#  'unstats.un.org',
#  'answers.com',
#  'memit.com',
#  'epicbrowser.com',
#  'datadeck.com',
#  'newspaperindex.com',
#  'ultraedit.com',
#  'visme.co',
#  'secure.flickr.com',
#  'veri.ly',
#  'greynet.org',
#  'generator.acmi.net.au',
#  'papaly.com',
#  'agoa.info',
#  'inkdrop.info',
#  'activeinboxhq.com',
#  'wn.com',
#  'commercial-register.sg.ch',
#  'sendspace.com',
#  'tagdef.com',
#  'impersonal.me',
#  'ucweb.com',
#  'complete.li',
#  'hdlab.stanford.edu',
#  'lookupuk.com',
#  'search.ch',
#  'verticalresponse.com',
#  'mailbox.org',
#  'lucidpress.com',
#  'thinglink.com',
#  'omnigroup.com',
#  'cloudfuze.com',
#  'riccardoscalco.github.io',
#  'powtoon.com',
#  'feed.janicek.co',
#  'biznar.com',
#  'stock.tookapic.com',
#  'mapalist.com',
#  'babelfish.com',
#  'slate.adobe.com',
#  'pmwiki.org',
#  'magportal.com',
#  'itranslateapp.com',
#  'readytalk.com',
#  'trueconf.com',
#  'digitalsamba.com',
#  'clearcontext.com',
#  'interment.net',
#  'workfront.com',
#  'dayboard.co',
#  'wridea.com',
#  'doingbusiness.org',
#  'getcrate.co',
#  '7photos.net',
#  'worldc.am',
#  'imgur.com',
#  'unicorns.io',
#  'infosniper.net',
#  'urlvoid.com',
#  'expertisefinder.com',
#  'audiense.com',
#  'wto.org',
#  'scribbleton.com',
#  'inkscape.org',
#  'htmlkit.com',
#  'twilert.com',
#  'usa.gov',
#  'liveslides.com',
#  'keepass.info',
#  'vk-to-rss.appspot.com',
#  'easel.ly',
#  'faostat3.fao.org',
#  'charts.hohli.com',
#  'data.oecd.org',
#  'otranscribe.com',
#  'barometer.agorapulse.com',
#  'xrayz.co.uk',
#  'slatebox.com',
#  'infobel.com',
#  'intracen.org',
#  'ip2location.com',
#  'todotxt.com',
#  'jobs.pl',
#  'gutenberg.org',
#  'refind.com',
#  'workflowy.com',
#  'interlude.fm',
#  'searchcode.com',
#  'transparentbusiness.com',
#  'standaert.net',
#  'draugiem.lv',
#  'bing.com',
#  'meetin.gs',
#  'simplyhired.com',
#  'nodebox.net',
#  'email-format.com',
#  'hypothes.is',
#  'maps.yahoo.com',
#  'sesric.org',
#  'cloudhq.net',
#  'team.fm',
#  'sway.com',
#  '2lingual.com',
#  'lib.umich.edu',
#  'befunky.com',
#  'sejda.com',
#  'deekit.com',
#  'photodex.com',
#  'guerrillamail.com',
#  'dnssec-debugger.verisignlabs.com',
#  'zooburst.com',
#  'developers.google.com',
#  'clipblast.com',
#  'andrewmohawk.com',
#  'ssd.eff.org',
#  'pulsedive.com',
#  'librarything.com',
#  'pidgin.im',
#  'wiki.gnome.org',
#  'animoto.com',
#  'geogig.org',
#  'prnewswire.com',
#  'simile-widgets.org',
#  'canva.com',
#  'ussearch.com',
#  'tagul.com',
#  'myslidepresenter.com',
#  'onlineocr.net',
#  'chrome.google.com',
#  'square.github.io',
#  'redditcommentsearch.com',
#  'unbabel.com',
#  'orange.fr',
#  'translate.google.com',
#  'verificationjunkie.com',
#  'encfsmp.sourceforge.net',
#  'nationalarchives.gov.uk',
#  'books.google.com',
#  'geosearchtool.com',
#  'happymetrix.com',
#  'teamgum.com',
#  'freekindlebooks.org',
#  'canada.ca',
#  'mylife.com',
#  'reddit.com',
#  'qlik.com',
#  'icontact.com',
#  'maperitive.net',
#  'reversegenie.com',
#  'spyfu.com',
#  'stormboard.com',
#  'pageflow.io',
#  'viewdns.info',
#  'comodo.com',
#  'timeline.knightlab.com',
#  'twitrss.me',
#  'whois.domaintools.com',
#  'egnyte.com',
#  'conceptboard.com',
#  'cvfox.com',
#  'ncbi.nlm.nih.gov',
#  'lifeofpix.com',
#  'toc.im',
#  'cyfe.com',
#  'urbanlegends.about.com',
#  'faceflow.com',
#  'tixeo.com',
#  'whiteboardfox.com',
#  'kred.com',
#  'mergentonline.com',
#  'statista.com',
#  'overviewdocs.com',
#  'sugarsync.com',
#  'boardreader.com',
#  'lookup-id.com',
#  'domaincrawler.com',
#  'searchisback.com',
#  'wikia.com',
#  'home.rootsweb.ancestry.com',
#  'chatsecure.org',
#  'melissadata.com',
#  'kartograph.org',
#  'i2ocr.com',
#  'socialbearing.com',
#  'sanebox.com',
#  'geohive.com',
#  'winds.getstream.io',
#  'hey.press',
#  'abine.com',
#  'personify.com',
#  'openlinkprofiler.org',
#  'digle.com',
#  'workflow.is',
#  'meekan.com',
#  'speakezee.org',
#  'newsblur.com',
#  'en.todoist.com',
#  'bloomingsoft.com',
#  'onlinenewspapers.com',
#  'oscobo.co.uk',
#  'huddle.com',
#  'feederator.org',
#  'esri.com',
#  'iconosquare.com',
#  'tweetpsych.com',
#  'lingvozone.com',
#  'geochirp.com',
#  'spyse.com',
#  'circos.ca',
#  'emaze.com',
#  'urlquery.net',
#  'network-tools.com',
#  'gengo.com',
#  'foolabs.com',
#  'tweetarchivist.com',
#  'timeglider.com',
#  'lib.utexas.edu',
#  'tweetreach.com',
#  'journals.cambridge.org',
#  'teamweek.com',
#  'basecamp.com',
#  'Knowem.com',
#  'mindmup.com',
#  'standout.adobe.com',
#  'infinitekind.com',
#  'headhunter.com',
#  'inc.com',
#  'sopdf.com',
#  'hooeeywebprint.com.s3-website-us-east-1.amazonaws.com',
#  'uvrx.com',
#  'vkparser.ru',
#  'eff.org',
#  'trooclick.com',
#  'awasu.com',
#  'pixlr.com',
#  'pennystocks.la',
#  'exif.regex.info',
#  'polymaps.org',
#  'kadaza.com',
#  'dokuwiki.org',
#  'tagboard.com',
#  'collegerecruiter.com',
#  'icerocket.com',
#  'fotoflexer.com',
#  'comtrade.un.org',
#  'social.downornot.com',
#  'pcloud.com',
#  'downloadhelper.net',
#  'mobipocket.com',
#  'lycos.com',
#  'citationsy.com',
#  'ziprecruiter.com',
#  'justdelete.me',
#  'beyond.com',
#  'mgmaps.com',
#  'mailtester.com',
#  'factcheck.org',
#  'snradar.azurewebsites.net',
#  'freemind.sourceforge.net',
#  'statscrop.com',
#  'jpgraph.net',
#  'fotoforensics.com',
#  'open-data.europa.eu',
#  'linkedin.com',
#  'yippy.com',
#  'fold3.com',
#  'advanseez.com',
#  'mailjet.com',
#  'colorbrewer2.org',
#  'campayn.com',
#  'scheduleonce.com',
#  'timetoast.com',
#  'webmeup.com',
#  'follow.net',
#  'tuzzit.com',
#  'newswise.com',
#  'sendicate.net',
#  'keywordtool.io',
#  'otixo.com',
#  'metacafe.com',
#  'httrack.com',
#  'liinira.uka.de',
#  'join.me',
#  'wetransfer.com',
#  'vimeo.com',
#  'deathtothestockphoto.com',
#  'tcpiputils.com',
#  'jetbrains.com',
#  'en.arguman.org',
#  'scribblemaps.com',
#  'pixelofink.com',
#  'sync.in',
#  'raindrop.io',
#  'duplicati.com',
#  'bookbub.com',
#  'reverso.net',
#  'goodnightchrome.com',
#  'data.worldbank.org',
#  'peekyou.com',
#  'microsystools.com',
#  'iloggo.com',
#  'planleaf.com',
#  'visualintelligence.co.nz',
#  'familytreenow.com',
#  'pixabay.com',
#  'ubersuggest.org',
#  'nos.twnsnd.co',
#  'deturl.com',
#  'newocr.com',
#  'getpocket.com',
#  'namecheckr.com',
#  'cia.gov',
#  'kloth.net',
#  'open.canada.ca',
#  'omnity.io',
#  'linphone.org',
#  'ebr.org',
#  'mindjet.com',
#  'jitsi.org',
#  'twchat.com',
#  'yasni.com',
#  'kompass.com',
#  'imageidentify.com',
#  'nutcache.com',
#  'le-tools.com',
#  'privazer.com',
#  'uis.unesco.org',
#  'scribble.wreally.com',
#  'tinygain.com',
#  'sources.com',
#  'talkwalker.com',
#  'dedicatedornot.com',
#  'twitter.com',
#  'cyberalert.com',
#  'crowdriff.com',
#  'hlwiki.slais.ubc.ca',
#  'lucidchart.com',
#  'sourceforge.net',
#  'pexels.com',
#  'calibre-ebook.com',
#  'dygraphs.com',
#  'flask.io',
#  'babblebay.com',
#  'jqplot.com',
#  'lucidmeetings.com',
#  'siteslike.com',
#  'fish4.co.uk',
#  'wordreference.com',
#  'shesource.org',
#  'maphub.net',
#  'glassdoor.com',
#  'abyznewslinks.com',
#  'scoot.co.uk',
#  'clarify.io',
#  'quora.com',
#  'whatismyipaddress.com',
#  'draw.to',
#  'myallsearch.com',
#  'get-nod.com',
#  'zapier.com',
#  'expertguide.com.au',
#  'proofhub.com',
#  'who.is',
#  'searchbug.com',
#  'zeadoo.com',
#  'here.com',
#  'ilo.org',
#  'mindomo.com',
#  'transferbigfiles.com',
#  'intodns.com',
#  'groups.yahoo.com',
#  'metatube.com',
#  'spark.apache.org',
#  'opinioncrawl.com',
#  'free-translator.com',
#  'comparably.com',
#  'quicktopic.com',
#  'yworks.com',
#  'activecollab.com',
#  'germ.io',
#  'support.apple.com',
#  'raw.densitydesign.org',
#  'richchartlive.com',
#  'evernote.com',
#  'wikimapia.org',
#  'kerrick.github.io',
#  'targethunter.net',
#  'klart.co',
#  'wekan.io',
#  'thescipub.com',
#  'quire.io',
#  'genealogybank.com',
#  'zulip.org',
#  'plunkettresearchonline.com',
#  'frame.io',
#  'decksetapp.com',
#  'egroupware.org',
#  'a.nnotate.com',
#  'tweetreports.com',
#  'spicynodes.org',
#  'podio.com',
#  'alltheinternet.com',
#  'buzzsumo.com',
#  'clammr.com',
#  'pearltrees.com',
#  'twiddla.com',
#  'squidnotes.com',
#  'images.google.com',
#  'knoema.com',
#  'greyguide.isti.cnr.it',
#  'pagepress.org',
#  'pinterest.com',
#  'facebook.com',
#  'ipchecking.com',
#  'charlieapp.com',
#  'apollohq.com',
#  'lib.stat.cmu.edu',
#  'teamworklive.com',
#  'webex.com',
#  'amazon.com',
#  'opengrey.eu',
#  'ipfingerprints.com',
#  'yougetsignal.com',
#  'itranslatevoice.com',
#  'team-pad.com',
#  'elegantt.com',
#  'foxitsoftware.com',
#  'ilmk.wordpress.com',
#  'majestic.com',
#  'orbisdirectory.bvdinfo.com',
#  'listenlive.eu',
#  'tripline.net',
#  'dragdis.com',
#  'nozbe.com',
#  'ip2geolocation.com',
#  'trendsmap.com',
#  'europages.co.uk',
#  'channelkit.com',
#  'verify-email.org',
#  'cachedview.com',
#  'wunderlist.com',
#  'browser.yandex.com',
#  'whatshouldireadnext.com',
#  'todoyu.com',
#  'pixxa.com',
#  'pingroupie.com',
#  'proxy-offline-browser.com',
#  'exif-search.com',
#  'bottlenose.com',
#  'photoshop.com',
#  'connect.data.com',
#  'archive.is',
#  'torchpad.com',
#  'sliderocket.com',
#  'whitepages.com',
#  'any.do',
#  'wdl.org',
#  'changedetect.com',
#  'foswiki.org',
#  'comindwork.com',
#  'jobsite.co.uk',
#  'newsnow.co.uk',
#  'nrcresearchpress.com',
#  'instantatlas.com',
#  'droplr.com',
#  'thebooksproject.co',
#  'freeoffice.com',
#  'metaproductsrevolver.com',
#  'netvibes.com',
#  'doesfollow.com',
#  'visualizefree.com',
#  'qubes-os.org',
#  'tweeten.xyz',
#  'vizualize.me',
#  'storymap.knightlab.com',
#  'backtweets.com',
#  'oecd.org',
#  'faststone.org',
#  'minbox.com',
#  'socialtext.com',
#  'yudu.com',
#  'padlet.com',
#  'authorea.com',
#  'tweetstats.com',
#  'topix.com',
#  'news.yahoo.com',
#  'documentcloud.org',
#  'gpgtools.org',
#  'yahoo.com',
#  'twbirthday.com',
#  'bizeurope.com',
#  'wordstotime.com',
#  'readgeek.com',
#  'nuzzel.com',
#  'microsoft.com',
#  'scribblar.com',
#  'bookseer.com',
#  'mapchart.net',
#  'hashatit.com',
#  'donottrack.us',
#  'stackfield.com',
#  'mindgenius.com',
#  'cepii.fr',
#  'fotor.com',
#  'pcr.uu.se',
#  'allthings.io',
#  'image.baidu.com',
#  'wepaste.com',
#  'lendle.me',
#  'products.office.com',
#  'manageflitter.com',
#  'kl1p.com',
#  'latinobarometro.org',
#  'rsssearchhub.com',
#  'ge.tt',
#  'online.sagepub.com',
#  'theglobalexperts.org',
#  'prnmedia.prnewswire.com',
#  'wits.worldbank.org',
#  'quadrigram.com',
#  'sno.phy.queensu.ca',
#  'ghostery.com',
#  'peoplesearch.net',
#  'bibsonomy.org',
#  'snappa.io',
#  'bridge.suumitsu.eu',
#  'weibo.com',
#  'peoplesearch.com.au',
#  'scholar.google.com',
#  'linkurio.us',
#  'mobilimeet.com',
#  'endnote.com',
#  'mozy.com',
#  'thepund.it',
#  'tools.verifyemailaddress.io',
#  'kanbantool.com',
#  'planzone.com',
#  'd3js.org',
#  'geosocialfootprint.com',
#  'tensons.com',
#  'capzles.com',
#  'memonic.com',
#  'quantcast.com',
#  'newsmap.jp',
#  'sitehoover.com',
#  'snoopsnoo.com',
#  'getnewsbot.com',
#  'groupmap.com',
#  'academic.research.microsoft.com',
#  'amnestyusa.org',
#  'campfirenow.com',
#  'ok.ru',
#  'digg.com',
#  'outertech.com',
#  'trexpertwitness.com',
#  'tweettunnel.com',
#  'tools.seochat.com',
#  'trends24.in',
#  'stackexchange.com',
#  'twiangulate.com',
#  'feed43.com',
#  'whoismind.com',
#  'all-io.net',
#  'signal.org',
#  'zanran.com',
#  'genealogylinks.net',
#  'metricsparrow.com',
#  'atavist.com',
#  'link.springer.com',
#  'teamup.com',
#  'gbimg.org',
#  'openlayers.org',
#  'search.nerdydata.com',
#  'allstocks.com',
#  'imageraider.com',
#  'us.teamblind.com',
#  'news.google.com',
#  'allmyfaves.com',
#  'doodle.com',
#  'cbr.ca',
#  'highcharts.com',
#  'anymeeting.com',
#  'keyworddiscovery.com',
#  'opendns.com',
#  'pdfexpert.com',
#  'newslink.org',
#  'statpedia.com',
#  'spaaze.com',
#  'neatline.org',
#  'offliberty.com',
#  'maxthon.com',
#  'viadesk.com',
#  'todo.ly',
#  'foogi.me',
#  'teamallocator.com',
#  'mywot.com',
#  'wayp.com',
#  'viamichelin.com',
#  'gigatweeter.com',
#  'mediabugs.org',
#  'trackpanel.net',
#  'dnsviz.net',
#  'mag.io',
#  'zingchart.com',
#  'screenleap.com',
#  'telegram.org',
#  'brianfolts.com',
#  'bis.org',
#  'ritetag.com',
#  'mapbox.com',
#  'opera.com',
#  'beakernotebook.com',
#  'wordtracker.com',
#  'pixcone.com',
#  'on.aol.com',
#  'cozi.com',
#  'tiki-toki.com',
#  'anydesk.com',
#  'allyoucanread.com',
#  'hipchat.com',
#  'slack.com',
#  'email-validator.net',
#  'kindlefeeder.com',
#  'images.search.yahoo.com',
#  'lightzoneproject.org',
#  'oovoo.com',
#  'dashthis.com',
#  'whatsapp.com',
#  'glasscubes.com',
#  'torrentfreak.com',
#  'blackboard.com',
#  'search.twitter.com',
#  'wikidpad.sourceforge.net',
#  'goofram.com',
#  'slidepresenter.com',
#  'ejfox.github.io',
#  'aweber.com',
#  'webwhiteboard.com',
#  'app.calculist.io',
#  'disconnect.me',
#  'news360.com',
#  'iwowwe.com',
#  'simplesignal.com',
#  'worldmap.harvard.edu',
#  'twicsy.com',
#  'gotomeeting.com',
#  'shorthand.com',
#  'madmimi.com',
#  'whoisology.com',
#  'autohotkey.com',
#  'quip.com',
#  'onemilliontweetmap.com',
#  'surfcanyon.com',
#  'binfire.com',
#  'kerika.com',
#  'gramfeed.com',
#  'tastekid.com',
#  'tiddlywiki.com',
#  'taskade.com',
#  'search.carrot2.org',
#  'alleba.com',
#  'metapicz.com',
#  'citeseer.ist.psu.edu',
#  'superdesk.org',
#  'infogr.am',
#  'shelfie.com',
#  'freeconferencecall.com',
#  'snapbird.org',
#  'klipfolio.com',
#  'liveleak.com',
#  'pressreader.com',
#  'thatoneprivacysite.net',
#  'pleco.com',
#  'encryptedcloud.com',
#  'mightymeeting.com',
#  'mypicsmap.com',
#  'torproject.org',
#  'lib.berkeley.edu',
#  'twingly.com',
#  'somcloud.com',
#  'tumblr.com',
#  'tib.eu',
#  'oedci.uspto.gov',
#  'info.tiki.org',
#  'ancestry.com',
#  'closr.it',
#  'twellow.com',
#  'feedly.com',
#  'crowdbase.com',
#  'hotspotshield.com',
#  'dict.cn',
#  'highfive.com',
#  'zapmeta.com',
#  'redditmetrics.com',
#  'hypestat.com',
#  'tweet-tag.com',
#  'opendatanetwork.com',
#  'exoplatform.com',
#  'helpmeviz.com',
#  'instantstreetview.com',
#  'zoominfo.com',
#  'hashtags.org',
#  'metta.io',
#  'noscript.net',
#  'webboar.com.w3snoop.com',
#  'ezilon.com',
#  'trackur.com',
#  'selfoss.aditu.de',
#  'faganfinder.com',
#  'base-search.net',
#  '411.com',
#  'france24.com',
#  'verificationhandbook.com',
#  'domainbigdata.com',
#  'gotinder.com',
#  'twipho.net',
#  'wiki.dbpedia.org',
#  'search.lycos.com',
#  'followerwonk.com',
#  'xmind.net',
#  'pageglimpse.com',
#  'webmii.com',
#  'ticktick.com',
#  'origin.mxtoolbox.com',
#  'geti2p.net',
#  'data.mashedworld.com',
#  'search.fb.com',
#  'titanpad.com',
#  'education.iseek.com',
#  'atomiks.github.io',
#  'ricochet.im',
#  'competeshark.com',
#  'manybooks.net',
#  'openculture.com',
#  'actionmint.com',
#  'en.mention.com',
#  'socialstats.ru',
#  'getminute.com',
#  'cvgadget.com',
#  'app.teachingprivacy.com',
#  'metachris.com',
#  'parrotread.com',
#  'venngage.com',
#  'builtwith.com',
#  'freeplane.sourceforge.net',
#  'emm.newsexplorer.eu',
#  'pdfsearchengine.info',
#  'itools.com',
#  'overdrive.com',
#  'scribd.com',
#  'facenama.com',
#  'newswhip.com',
#  'hightail.com',
#  'flowdock.com',
#  'protonmail.com',
#  'newsinshorts.com',
#  'loyalbooks.com',
#  'dnshistory.org',
#  'mashme.tv',
#  'zabasearch.com',
#  'workboard.com',
#  'talky.io',
#  'socialrank.com',
#  'axantum.com',
#  'myfav.es',
#  'zeetings.com',
#  'mustbepresent.com',
#  'zintro.com',
#  'followcheck.com',
#  'vcasmo.com',
#  'liveconferencepro.com',
#  'restya.com',
#  'naver.com',
#  'zoom.us',
#  'librestock.com',
#  'philogb.github.io',
#  'kindleworld.blogspot.com',
#  'onelook.com',
#  'sourcefabric.org',
#  'oxfordjournals.org',
#  'hugin.sourceforge.net',
#  'slideidea.com',
#  'atlas.cid.harvard.edu',
#  'edynco.com',
#  'narro.co',
#  'academia.edu',
#  'keep.google.com',
#  'mapquest.com',
#  'iplocation.net',
#  'eu.wiley.com',
#  'redirectdetective.com',
#  'mapbuildr.com',
#  'kaboompics.com',
#  'etools.ch',
#  'yandex.com',
#  'piriform.com',
#  'grass.osgeo.org',
#  'meet.fm',
#  'en.wikipedia.org',
#  'hdr.undp.org',
#  'alexa.com',
#  'quicksprout.com',
#  'eblvd.com',
#  'wappwolf.com',
#  'elink.io',
#  'noslang.com',
#  'visjs.org',
#  'wolframalpha.com',
#  'izito.com',
#  'imf.org',
#  'candybank.com',
#  'theoldreader.com',
#  'casual.pm',
#  'cardboardit.com',
#  'piclits.com',
#  'annotatorjs.org',
#  'gnupg.org',
#  'mochimarks.com',
#  'reunion.com',
#  'masterpasswordapp.com',
#  'whoishostingthis.com',
#  'soovle.com',
#  'changedetection.com',
#  'alumni.net',
#  'fullfact.org',
#  'polarr.co',
#  'nixory.sourceforge.net',
#  'rescuetime.com',
#  'authorstream.com',
#  'infiniteconferencing.com',
#  'transparency.org',
#  'dropcanvas.com',
#  'mylifeorganized.net',
#  'mozilla.org',
#  'gapminder.org',
#  'burrrd.com',
#  'iea.org',
#  'start.me',
#  ...}

# %% [markdown]
# # Characteristics_organization function
#
# Similarly to the values_and_frequencies function, this function returns a dictionary that maps every unique value with its number of occurrences. The difference is that this function is made specifically to generate a mapping for the third feature (Description) and does not allow a minimum number of repetitions.

# %%
def characteristics_organization(where_to_look_for):
    
    '''
    Takes a list of lists (every sublist represents a field in a database) and generates a dictionary that maps the names of the
    third field with its occurrences. Entries with no information on the third field are stored as n/a.
    '''
    # The field is first filtered from the document. A list of strings containing the field of interest is generated.
    descriptions = features_picker_cleaner(where_to_look_for, 3)
    
    # Frequency of occurrence is calculated by passing the filtered field into the values_and_frequencies function. 
    return values_and_frequencies(descriptions)

print(characteristics_organization(cleaned_data))
# Out:
# {'Buscador foros': 8, 'Browsers': 17, 'Buscador genérico': 18, 'Dashboard Tools': 11, 'Meta buscador': 14, 'Buscador especializado': 10, 'Herramientas Instagram': 7, 'Buscador código': 3, 'Redes Sociales': 42, 'n/a': 1432, 'Q&A Sites': 6, 'Buscador visual': 2, 'Herramientas Twitter': 82, 'Wikis': 14, 'Buscador local': 13, 'Data and Statistics': 80, 'Herramientas Pinterest': 1, 'Buscadores por similitud': 3, 'Herramientas Reddit': 10, 'Buscador de contenidos': 11, 'Buscador blogs': 5, 'Herramientas Facebook': 1}
